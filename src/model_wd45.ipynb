# %% [markdown]
# # Treeffuser Warm and Dry Climate Model RCP 4.5 training and validation

# %%
# %run -i 'droughtpredictor.py'

# %%
from droughtpredictor import DroughtPredictor

# Initialize the predictor
predictor = DroughtPredictor(
    min_year=1950,
    max_year=2013,
    result_dir='results',
    data_simul = 'wd45'
)

# # Option 1: Run the complete pipeline
# predictor.run_complete_pipeline(
#     historical_file='final_historical.csv',
#     future_file='future_all_df_wd_85.csv'
# )

# Option 2: Run individual steps for more control
predictor.load_data('final_historical.csv', 'future_all_df_wd_45.csv')
predictor.prepare_features()
predictor.select_features()
predictor.cross_validate(n_splits=5)
predictor.train_final_models()
predictor.make_predictions()
predictor.create_visualizations()
predictor.create_uncertainty_visualization()
predictor.generate_report()

print("Drought prediction completed successfully!")
# Out:
# ================================================================================
# ========================== LOADING AND PREPARING DATA ==========================
# ================================================================================
# Historical data: 768 rows from 1950-01-01 00:00:00 to 2013-12-01 00:00:00
# Future data: 900 rows from 2025-01-01 00:00:00 to 2099-12-01 00:00:00
#
# ================================================================================
# ========================= ENHANCED FEATURE ENGINEERING =========================
# ================================================================================
#
# Target variable statistics:
# D0: min=0.00, max=100.10, mean=42.54, median=31.20
# D1: min=0.00, max=100.00, mean=30.76, median=9.30
# D2: min=0.00, max=100.00, mean=15.37, median=0.00
# D3: min=0.00, max=95.09, mean=6.97, median=0.00
# D4: min=0.00, max=71.80, mean=1.85, median=0.00
#
# D4 binary class distribution: D4_binary
# 0    653
# 1    115
# Name: count, dtype: int64
# No NaN values in the feature-engineered historical data
# Total number of features: 79
# Base features: 8
# Seasonal features: 6
# Rolling features: 9
# Interaction features: 6
# Derived features: 50
#
# ================================================================================
# ========================= FEATURE IMPORTANCE ANALYSIS ==========================
# ================================================================================
#
# Feature importance for D0:
#
# Top important features:
#   D0_lag_1: 0.8110
#   rainfall: 0.0199
#   rainfall_roll_12: 0.0147
#   airtemp_runoff_interaction: 0.0122
#   airtemp_ev_interaction: 0.0106
#   rainfall_roll_6: 0.0101
#   rainfall_runoff_interaction: 0.0071
#   D1_lag_1: 0.0069
#   airtemp_roll_3: 0.0068
#   sm_roll_6: 0.0067
#   airtemp_roll_6: 0.0065
#   rainfall_roll_3: 0.0056
#   airtemp_roll_12: 0.0045
#   sm: 0.0043
#   ev: 0.0035
#   rainfall_baseflow_interaction: 0.0034
#   snowwater: 0.0032
#   baseflow: 0.0031
#   sm_roll_12: 0.0031
#   D0_lag_2: 0.0028
# Selected 12 features for D0
#
# Feature importance for D1:
#
# Top important features:
#   D1_lag_1: 0.7216
#   D0_lag_1: 0.0833
#   airtemp_runoff_interaction: 0.0208
#   rainfall: 0.0149
#   rainfall_runoff_interaction: 0.0132
#   rainfall_roll_12: 0.0101
#   airtemp_roll_6: 0.0073
#   rainfall_roll_6: 0.0065
#   airtemp_ev_interaction: 0.0057
#   sm_roll_6: 0.0056
#   rainfall_roll_3: 0.0053
#   runoff: 0.0050
#   airtemp_roll_3: 0.0046
#   rainfall_baseflow_interaction: 0.0044
#   D2_lag_1: 0.0043
#   sm_ev_interaction: 0.0042
#   sm_roll_12: 0.0041
#   ev: 0.0040
#   D1_lag_2: 0.0039
#   airtemp_roll_12: 0.0039
# Selected 12 features for D1
#
# Feature importance for D2:
#
# Top important features:
#   D2_lag_1: 0.6795
#   D1_lag_1: 0.0671
#   rainfall_roll_12: 0.0273
#   sm_roll_12: 0.0121
#   rainfall: 0.0121
#   rainfall_roll_6: 0.0117
#   sm_roll_6: 0.0114
#   airtemp_ev_interaction: 0.0095
#   D2_lag_2: 0.0087
#   airtemp_runoff_interaction: 0.0083
#   D1_lag_2: 0.0076
#   snowfall: 0.0071
#   D0_lag_1: 0.0060
#   baseflow: 0.0056
#   airtemp_roll_12: 0.0054
#   rainfall_baseflow_interaction: 0.0054
#   airtemp_roll_6: 0.0052
#   D1_lag_3: 0.0050
#   airtemp_roll_3: 0.0044
#   airtemp: 0.0044
# Selected 17 features for D2
#
# Feature importance for D3:
#
# Top important features:
#   D3_lag_1: 0.6005
#   rainfall_roll_12: 0.0683
#   D2_lag_1: 0.0571
#   sm_roll_6: 0.0238
#   sm_roll_12: 0.0218
#   D2_lag_2: 0.0127
#   airtemp_ev_interaction: 0.0113
#   sm_baseflow_interaction: 0.0113
#   snowwater: 0.0111
#   rainfall: 0.0102
#   baseflow: 0.0101
#   sm: 0.0091
#   ev: 0.0084
#   rainfall_roll_6: 0.0083
#   D4_lag_1: 0.0078
#   airtemp_runoff_interaction: 0.0076
#   rainfall_roll_3: 0.0068
#   D1_lag_1: 0.0066
#   airtemp_roll_6: 0.0063
#   sm_roll_3: 0.0058
# Selected 20 features for D3
#
# Feature importance for D4:
#
# Top important features:
#   D4_lag_1: 0.4011
#   D2_lag_1: 0.0491
#   baseflow: 0.0479
#   sm_roll_6: 0.0321
#   D3_lag_1: 0.0253
#   sm_roll_3: 0.0219
#   airtemp_ev_interaction: 0.0184
#   sm_baseflow_interaction: 0.0184
#   rainfall_roll_6: 0.0179
#   runoff: 0.0156
#   rainfall_roll_12: 0.0153
#   D0_lag_6: 0.0151
#   ev: 0.0150
#   rainfall_roll_3: 0.0136
#   D3_lag_2: 0.0134
#   airtemp_roll_3: 0.0129
#   D3_lag_3: 0.0123
#   airtemp_roll_6: 0.0122
#   rainfall_baseflow_interaction: 0.0113
#   sm_roll_12: 0.0110
# Selected 30 features for D4
#
# ================================================================================
# ========================= TIME SERIES CROSS-VALIDATION =========================
# ================================================================================
# Time series cross-validation with 5 splits
# Data from 1950 to 2013
# Approximate split years: [1962, 1974, 1986, 1998]
#
# Fold 1/5
# Train period: 1950-1960 (128 samples)
# Test period: 1960-1971 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.7980, MAE = 11.6900, RMSE = 16.0000
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.7423, MAE = 11.4551, RMSE = 16.6774
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.5646, MAE = 8.8600, RMSE = 14.7248
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.4936, MAE = 4.9309, RMSE = 10.2891
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.4911, MAE = 2.1320, RMSE = 4.7812
# D4 Binary Classification: Accuracy = 0.8438, F1 = 0.6296
# Precision = 0.5862, Recall = 0.6800
#
# Fold 2/5
# Train period: 1950-1971 (256 samples)
# Test period: 1971-1981 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8150, MAE = 9.8492, RMSE = 15.8391
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.7834, MAE = 9.8524, RMSE = 14.9782
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.5718, MAE = 7.4711, RMSE = 14.2122
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.4598, MAE = 4.7972, RMSE = 11.8893
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.2159, MAE = 2.5299, RMSE = 8.8844
# D4 Binary Classification: Accuracy = 0.9062, F1 = 0.6667
# Precision = 0.7059, Recall = 0.6316
#
# Fold 3/5
# Train period: 1950-1981 (384 samples)
# Test period: 1982-1992 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8702, MAE = 6.8808, RMSE = 12.0056
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.8721, MAE = 5.3354, RMSE = 10.5641
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.7249, MAE = 4.5455, RMSE = 10.8728
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.6357, MAE = 3.3330, RMSE = 9.5538
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.1579, MAE = 2.0676, RMSE = 8.8945
# D4 Binary Classification: Accuracy = 0.8984, F1 = 0.5517
# Precision = 0.5714, Recall = 0.5333
#
# Fold 4/5
# Train period: 1950-1992 (512 samples)
# Test period: 1992-2003 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8147, MAE = 12.0832, RMSE = 17.8474
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.8289, MAE = 9.6991, RMSE = 15.3977
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.7415, MAE = 9.0238, RMSE = 15.4608
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.7228, MAE = 6.0240, RMSE = 11.9358
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = -0.9129, MAE = 3.4816, RMSE = 7.9254
# D4 Binary Classification: Accuracy = 0.7969, F1 = 0.3158
# Precision = 0.3529, Recall = 0.2857
#
# Fold 5/5
# Train period: 1950-2003 (640 samples)
# Test period: 2003-2013 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8339, MAE = 10.7769, RMSE = 16.7392
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.7818, MAE = 13.3098, RMSE = 20.2187
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.8026, MAE = 9.6873, RMSE = 14.9527
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.8590, MAE = 4.3456, RMSE = 8.5590
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.0000, MAE = 2.1046, RMSE = 4.4157
# D4 Binary Classification: Accuracy = 0.9062, F1 = 0.0000
# Precision = 0.0000, Recall = 0.0000
#
# Average Cross-Validation Results:
# D0: R² = 0.8264, MAE = 10.2560, RMSE = 15.6863
# D1: R² = 0.8017, MAE = 9.9304, RMSE = 15.5672
# D2: R² = 0.6811, MAE = 7.9175, RMSE = 14.0447
# D3: R² = 0.6342, MAE = 4.6862, RMSE = 10.4454
# D4: R² = -0.0096, MAE = 2.4631, RMSE = 6.9802
#
# D4 Binary Classification: Accuracy = 0.8703, F1 = 0.4328
# Precision = 0.4433, Recall = 0.4261
#
# Performance metrics saved to 'results/performance_metrics.json'
#
# ================================================================================
# ============================= FINAL MODEL TRAINING =============================
# ================================================================================
# Training final model for D0...
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# Training final model for D1...
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# Training final model for D2...
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# Training final model for D3...
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# Training final model for D4...
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# Training final D4 binary classification model...
#
# ================================================================================
# ============================== MAKING PREDICTIONS ==============================
# ================================================================================
# Type of self.future_df_csv: <class 'str'>
# Is self.future_df a DataFrame? True
#
# Starting autoregressive prediction with domain knowledge...
# Combined data shape: (1668, 24)
# Prediction period: 2025-01-01 00:00:00 to 2099-12-01 00:00:00
# Future data starts at index 768
# Predicting for 2025-01... Done
# Predicting for 2025-02... Done
# Predicting for 2025-03... Done
# Predicting for 2025-04... Done
# Predicting for 2025-05... Done
# Predicting for 2025-06... Done
# Predicting for 2025-07... Done
# Predicting for 2025-08... Done
# Predicting for 2025-09... Done
# Predicting for 2025-10... Done
# Predicting for 2025-11... Done
# Predicting for 2025-12... Done
# Predicting for 2026-01... Done
# Predicting for 2026-02... Done
# Predicting for 2026-03... Done
# Predicting for 2026-04... Done
# Predicting for 2026-05... Done
# Predicting for 2026-06... Done
# Predicting for 2026-07... Done
# Predicting for 2026-08... Done
# Predicting for 2026-09... Done
# Predicting for 2026-10... Done
# Predicting for 2026-11... Done
# Predicting for 2026-12... Done
# Predicting for 2027-01... Done
# Predicting for 2027-02... Done
# Predicting for 2027-03... Done
# Predicting for 2027-04... Done
# Predicting for 2027-05... Done
# Predicting for 2027-06... Done
# Predicting for 2027-07... Done
# Predicting for 2027-08... Done
# Predicting for 2027-09... Done
# Predicting for 2027-10... Done
# Predicting for 2027-11... Done
# Predicting for 2027-12... Done
# Predicting for 2028-01... Done
# Predicting for 2028-02... Done
# Predicting for 2028-03... Done
# Predicting for 2028-04... Done
# Predicting for 2098-09... Done
# Predicting for 2098-10... Done
# Predicting for 2098-11... Done
# Predicting for 2098-12... Done
# Predicting for 2099-01... Done
# Predicting for 2099-02... Done
# Predicting for 2099-03... Done
# Predicting for 2099-04... Done
# Predicting for 2099-05... Done
# Predicting for 2099-06... Done
# Predicting for 2099-07... Done
# Predicting for 2099-08... Done
# Predicting for 2099-09... Done
# Predicting for 2099-10... Done
# Predicting for 2099-11... Done
# Predicting for 2099-12... Done
#
# Prediction statistics by target:
# D0: mean=69.49, std=34.25, min=0.00, max=100.00
# D1: mean=61.89, std=36.23, min=0.00, max=100.00
# D2: mean=43.63, std=30.95, min=0.00, max=100.00
# D3: mean=25.86, std=24.88, min=0.00, max=95.09
# D4: mean=3.49, std=2.88, min=0.00, max=21.49
#
# Applying final consistency constraints...
# Predictions saved to 'results/wd45/wd45_future_drought_predictions.csv'
#
# ================================================================================
# ========================== VISUALIZATION AND ANALYSIS ==========================
# ================================================================================
# Visualization saved to 'results/drought_predictions.png'
#
# ================================================================================
# ====================== D4 BINARY CLASSIFICATION ANALYSIS =======================
# ================================================================================
# Predicted D4 drought events in future data: 13.0 (1.4%)
# D4 binary classification visualization saved to 'results/wd45/wd45_d4_binary_classification.png'
# Final predictions with binary classification saved to 'results/wd45/wd45_future_drought_predictions_with_binary.csv'
#
# ================================================================================
# ========================== UNCERTAINTY VISUALIZATION ===========================
# ================================================================================
# Generating uncertainty bands for D0 using bootstrap method...
# Generating uncertainty bands for D1 using bootstrap method...
# Generating uncertainty bands for D2 using bootstrap method...
# Generating uncertainty bands for D3 using bootstrap method...
# Generating uncertainty bands for D4 using bootstrap method...
# Uncertainty visualization saved to 'results/wd45/wd45_drought_predictions_uncertainty.png'
#
# ================================================================================
# ================================= FINAL REPORT =================================
# ================================================================================
#
# ===== DROUGHT PREDICTION MODEL PERFORMANCE REPORT =====
#
# MODEL PERFORMANCE SUMMARY:
# D0 Regression Performance:
#   R² Score: 0.8264
#   MAE: 10.2560
#   RMSE: 15.6863
#
# D1 Regression Performance:
#   R² Score: 0.8017
#   MAE: 9.9304
#   RMSE: 15.5672
#
# D2 Regression Performance:
#   R² Score: 0.6811
#   MAE: 7.9175
#   RMSE: 14.0447
#
# D3 Regression Performance:
#   R² Score: 0.6342
#   MAE: 4.6862
#   RMSE: 10.4454
#
# D4 Regression Performance:
#   R² Score: -0.0096
#   MAE: 2.4631
#   RMSE: 6.9802
#
# D4 Binary Classification Performance:
#   Accuracy: 0.8703
#   Precision: 0.4433
#   Recall: 0.4261
#   F1 Score: 0.4328
#
#
# VISUALIZATION AND RESULTS:
# All predictions, visualizations, and performance metrics have been saved to the results directory:
# - future_drought_predictions.csv: Predicted drought indices
# - future_drought_predictions_with_binary.csv: Predictions with binary classification
# - performance_metrics.json: Detailed performance metrics
# - drought_predictions.png: Time series visualizations
# - drought_predictions_uncertainty.png: Uncertainty visualization
# - d4_binary_classification.png: D4 classification analysis
#
# Drought prediction model completed successfully.
#
# Total execution time: 3503.34 seconds (58.39 minutes)
# Report saved to 'results/wd45/wd45_model_report.txt'
# Drought prediction completed successfully!
