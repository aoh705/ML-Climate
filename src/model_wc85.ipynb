# %% [markdown]
# # Wet and Cool Climate Model RCP 8.5 training and prediction

# %%
# %run -i 'droughtpredictor.py'

# %%
from droughtpredictor import DroughtPredictor

# Initialize the predictor
predictor = DroughtPredictor(
    min_year=1950,
    max_year=2013,
    result_dir='results',
    data_simul = 'wc85'
)

# # Option 1: Run the complete pipeline
# predictor.run_complete_pipeline(
#     historical_file='final_historical.csv',
#     future_file='future_all_df_wd_85.csv'
# )

# Option 2: Run individual steps for more control
predictor.load_data('final_historical.csv', 'future_all_df_wc_85.csv')
predictor.prepare_features()
predictor.select_features()
predictor.cross_validate(n_splits=5)
predictor.train_final_models()
predictor.make_predictions()
predictor.create_visualizations()
predictor.create_uncertainty_visualization()
predictor.generate_report()

print("Drought prediction completed successfully!")
# Out:
# ================================================================================
# ========================== LOADING AND PREPARING DATA ==========================
# ================================================================================
#
#  FOR TESTING PURPOSES: DOING SUBSET OF DATA
# Historical data: 768 rows from 1950-01-01 00:00:00 to 2013-12-01 00:00:00
# Future data: 23 rows from 2025-01-01 00:00:00 to 2026-11-01 00:00:00
#
# ================================================================================
# ========================= ENHANCED FEATURE ENGINEERING =========================
# ================================================================================
#
# Target variable statistics:
# D0: min=0.00, max=100.10, mean=42.54, median=31.20
# D1: min=0.00, max=100.00, mean=30.76, median=9.30
# D2: min=0.00, max=100.00, mean=15.37, median=0.00
# D3: min=0.00, max=95.09, mean=6.97, median=0.00
# D4: min=0.00, max=71.80, mean=1.85, median=0.00
#
# D4 binary class distribution: D4_binary
# 0    653
# 1    115
# Name: count, dtype: int64
# No NaN values in the feature-engineered historical data
# Total number of features: 59
# Base features: 8
# Seasonal features: 6
# Rolling features: 9
# Interaction features: 6
# Derived features: 30
#
# ================================================================================
# ========================= FEATURE IMPORTANCE ANALYSIS ==========================
# ================================================================================
#
# Feature importance for D0:
#
# Top important features:
#   D0_lag_1: 0.8110
#   rainfall: 0.0202
#   rainfall_roll_12: 0.0150
#   airtemp_runoff_interaction: 0.0124
#   rainfall_roll_6: 0.0107
#   airtemp_ev_interaction: 0.0107
#   D1_lag_1: 0.0071
#   airtemp_roll_3: 0.0071
#   rainfall_runoff_interaction: 0.0071
#   sm_roll_6: 0.0066
#   airtemp_roll_6: 0.0065
#   rainfall_roll_3: 0.0056
#   airtemp_roll_12: 0.0047
#   sm: 0.0044
#   ev: 0.0036
#   sm_roll_12: 0.0034
#   snowwater: 0.0034
#   rainfall_baseflow_interaction: 0.0034
#   D1_lag_2: 0.0031
#   airtemp: 0.0030
# Selected 12 features for D0
#
# Feature importance for D1:
#
# Top important features:
#   D1_lag_1: 0.7217
#   D0_lag_1: 0.0833
#   airtemp_runoff_interaction: 0.0207
#   rainfall: 0.0153
#   rainfall_runoff_interaction: 0.0135
#   rainfall_roll_12: 0.0102
#   airtemp_roll_6: 0.0070
#   rainfall_roll_6: 0.0066
#   sm_roll_6: 0.0058
#   airtemp_ev_interaction: 0.0057
#   rainfall_roll_3: 0.0054
#   runoff: 0.0052
#   sm_roll_12: 0.0050
#   D1_lag_2: 0.0047
#   D2_lag_1: 0.0046
#   airtemp_roll_3: 0.0044
#   sm_ev_interaction: 0.0043
#   ev: 0.0043
#   airtemp_roll_12: 0.0042
#   rainfall_baseflow_interaction: 0.0039
# Selected 12 features for D1
#
# Feature importance for D2:
#
# Top important features:
#   D2_lag_1: 0.6806
#   D1_lag_1: 0.0668
#   rainfall_roll_12: 0.0281
#   rainfall: 0.0123
#   rainfall_roll_6: 0.0123
#   sm_roll_12: 0.0116
#   sm_roll_6: 0.0112
#   D2_lag_2: 0.0097
#   airtemp_ev_interaction: 0.0093
#   airtemp_runoff_interaction: 0.0085
#   D1_lag_2: 0.0077
#   snowfall: 0.0074
#   baseflow: 0.0065
#   D0_lag_1: 0.0064
#   airtemp_roll_12: 0.0057
#   airtemp: 0.0055
#   rainfall_roll_3: 0.0052
#   airtemp_roll_6: 0.0050
#   snowwater: 0.0049
#   D1_lag_3: 0.0048
# Selected 18 features for D2
#
# Feature importance for D3:
#
# Top important features:
#   D3_lag_1: 0.6017
#   rainfall_roll_12: 0.0696
#   D2_lag_1: 0.0571
#   sm_roll_12: 0.0259
#   sm_roll_6: 0.0251
#   snowwater: 0.0120
#   airtemp_ev_interaction: 0.0117
#   sm_baseflow_interaction: 0.0110
#   rainfall: 0.0108
#   baseflow: 0.0103
#   rainfall_roll_6: 0.0087
#   sm: 0.0084
#   ev: 0.0078
#   D2_lag_2: 0.0078
#   D4_lag_1: 0.0078
#   rainfall_roll_3: 0.0069
#   airtemp_runoff_interaction: 0.0067
#   D1_lag_1: 0.0062
#   sm_roll_3: 0.0061
#   airtemp_roll_6: 0.0060
# Selected 20 features for D3
#
# Feature importance for D4:
#
# Top important features:
#   D4_lag_1: 0.4027
#   D2_lag_1: 0.0517
#   baseflow: 0.0487
#   sm_roll_6: 0.0327
#   D3_lag_1: 0.0266
#   sm_roll_3: 0.0251
#   D3_lag_3: 0.0232
#   sm_baseflow_interaction: 0.0197
#   airtemp_roll_3: 0.0181
#   airtemp_ev_interaction: 0.0178
#   rainfall_roll_6: 0.0160
#   ev: 0.0158
#   rainfall_roll_3: 0.0147
#   rainfall_roll_12: 0.0144
#   airtemp_runoff_interaction: 0.0143
#   D3_lag_2: 0.0142
#   runoff: 0.0139
#   sm_roll_12: 0.0121
#   snowwater: 0.0115
#   sm: 0.0111
# Selected 30 features for D4
#
# ================================================================================
# ========================= TIME SERIES CROSS-VALIDATION =========================
# ================================================================================
# Time series cross-validation with 5 splits
# Data from 1950 to 2013
# Approximate split years: [1962, 1974, 1986, 1998]
#
# Fold 1/5
# Train period: 1950-1960 (128 samples)
# Test period: 1960-1971 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.7973, MAE = 11.8976, RMSE = 16.0308
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.7486, MAE = 11.1452, RMSE = 16.4721
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.5329, MAE = 8.8213, RMSE = 15.2524
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.5335, MAE = 5.0369, RMSE = 9.8751
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.5644, MAE = 1.8718, RMSE = 4.4236
# D4 Binary Classification: Accuracy = 0.8438, F1 = 0.6296
# Precision = 0.5862, Recall = 0.6800
#
# Fold 2/5
# Train period: 1950-1971 (256 samples)
# Test period: 1971-1981 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8152, MAE = 9.9311, RMSE = 15.8335
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.7783, MAE = 10.0269, RMSE = 15.1525
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.6241, MAE = 6.8897, RMSE = 13.3168
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.4900, MAE = 4.5974, RMSE = 11.5518
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.2303, MAE = 2.5174, RMSE = 8.8025
# D4 Binary Classification: Accuracy = 0.9141, F1 = 0.7027
# Precision = 0.7222, Recall = 0.6842
#
# Fold 3/5
# Train period: 1950-1981 (384 samples)
# Test period: 1982-1992 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8636, MAE = 7.2153, RMSE = 12.3067
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.8705, MAE = 5.3712, RMSE = 10.6302
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.7063, MAE = 4.6635, RMSE = 11.2347
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.6213, MAE = 3.2761, RMSE = 9.7406
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.2994, MAE = 1.8938, RMSE = 8.1124
# D4 Binary Classification: Accuracy = 0.9062, F1 = 0.5714
# Precision = 0.6154, Recall = 0.5333
#
# Fold 4/5
# Train period: 1950-1992 (512 samples)
# Test period: 1992-2003 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8157, MAE = 12.0150, RMSE = 17.7983
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.8269, MAE = 9.6741, RMSE = 15.4884
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.7210, MAE = 9.2407, RMSE = 16.0618
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.6871, MAE = 6.3365, RMSE = 12.6808
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = -1.0201, MAE = 3.4150, RMSE = 8.1444
# D4 Binary Classification: Accuracy = 0.8047, F1 = 0.4186
# Precision = 0.4091, Recall = 0.4286
#
# Fold 5/5
# Train period: 1950-2003 (640 samples)
# Test period: 2003-2013 (128 samples)
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# D0 results: R² = 0.8305, MAE = 10.8470, RMSE = 16.9118
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# D1 results: R² = 0.7749, MAE = 13.4953, RMSE = 20.5345
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# D2 results: R² = 0.8294, MAE = 8.7468, RMSE = 13.9014
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# D3 results: R² = 0.8555, MAE = 4.5568, RMSE = 8.6635
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# D4 results: R² = 0.0000, MAE = 0.6187, RMSE = 1.6612
# D4 Binary Classification: Accuracy = 0.9453, F1 = 0.0000
# Precision = 0.0000, Recall = 0.0000
#
# Average Cross-Validation Results:
# D0: R² = 0.8245, MAE = 10.3812, RMSE = 15.7762
# D1: R² = 0.7998, MAE = 9.9426, RMSE = 15.6555
# D2: R² = 0.6827, MAE = 7.6724, RMSE = 13.9534
# D3: R² = 0.6375, MAE = 4.7607, RMSE = 10.5024
# D4: R² = 0.0148, MAE = 2.0633, RMSE = 6.2288
#
# D4 Binary Classification: Accuracy = 0.8828, F1 = 0.4645
# Precision = 0.4666, Recall = 0.4652
#
# Performance metrics saved to 'results/performance_metrics.json'
#
# ================================================================================
# ============================= FINAL MODEL TRAINING =============================
# ================================================================================
# Training final model for D0...
# Training model for D0...
#   Successfully trained TreeFFuser with 150 estimators
# Training final model for D1...
# Training model for D1...
#   Successfully trained TreeFFuser with 150 estimators
# Training final model for D2...
# Training model for D2...
#   Successfully trained TreeFFuser with 100 estimators
# Training final model for D3...
# Training model for D3...
#   Successfully trained TreeFFuser with 100 estimators
# Training final model for D4...
# Training model for D4...
#   Successfully trained TreeFFuser with 150 estimators
# Training final D4 binary classification model...
#
# ================================================================================
# ============================== MAKING PREDICTIONS ==============================
# ================================================================================
#
# Starting autoregressive prediction with domain knowledge...
# Combined data shape: (791, 24)
# Prediction period: 2025-01-01 00:00:00 to 2026-11-01 00:00:00
# Future data starts at index 768
# Predicting for 2025-01... Done
# Predicting for 2025-02... Done
# Predicting for 2025-03... Done
# Predicting for 2025-04... Done
# Predicting for 2025-05... Done
# Predicting for 2025-06... Done
# Predicting for 2025-07... Done
# Predicting for 2025-08... Done
# Predicting for 2025-09... Done
# Predicting for 2025-10... Done
# Predicting for 2025-11... Done
# Predicting for 2025-12... Done
# Predicting for 2026-01... Done
# Predicting for 2026-02... Done
# Predicting for 2026-03... Done
# Predicting for 2026-04... Done
# Predicting for 2026-05... Done
# Predicting for 2026-06... Done
# Predicting for 2026-07... Done
# Predicting for 2026-08... Done
# Predicting for 2026-09... Done
# Predicting for 2026-10... Done
# Predicting for 2026-11... Done
#
# Prediction statistics by target:
# D0: mean=69.68, std=28.67, min=13.64, max=100.00
# D1: mean=63.86, std=29.98, min=10.44, max=100.00
# D2: mean=37.08, std=19.38, min=0.00, max=73.89
# D3: mean=17.07, std=9.15, min=0.00, max=31.71
# D4: mean=4.46, std=2.74, min=0.00, max=13.55
#
# Applying final consistency constraints...
# Predictions saved to 'results/future_drought_predictions.csv'
#
# ================================================================================
# ========================== VISUALIZATION AND ANALYSIS ==========================
# ================================================================================
# Visualization saved to 'results/drought_predictions.png'
#
# ================================================================================
# ====================== D4 BINARY CLASSIFICATION ANALYSIS =======================
# ================================================================================
# Predicted D4 drought events in future data: 1.0 (4.3%)
# D4 binary classification visualization saved to 'results/d4_binary_classification.png'
# Final predictions with binary classification saved to 'results/future_drought_predictions_with_binary.csv'
#
# ================================================================================
# ========================== UNCERTAINTY VISUALIZATION ===========================
# ================================================================================
# Generating uncertainty bands for D0 using bootstrap method...
# Generating uncertainty bands for D1 using bootstrap method...
# Generating uncertainty bands for D2 using bootstrap method...
# Generating uncertainty bands for D3 using bootstrap method...
# Generating uncertainty bands for D4 using bootstrap method...
# Uncertainty visualization saved to 'results/drought_predictions_uncertainty.png'
#
# ================================================================================
# ================================= FINAL REPORT =================================
# ================================================================================
#
# ===== DROUGHT PREDICTION MODEL PERFORMANCE REPORT =====
#
# MODEL PERFORMANCE SUMMARY:
# D0 Regression Performance:
#   R² Score: 0.8245
#   MAE: 10.3812
#   RMSE: 15.7762
#
# D1 Regression Performance:
#   R² Score: 0.7998
#   MAE: 9.9426
#   RMSE: 15.6555
#
# D2 Regression Performance:
#   R² Score: 0.6827
#   MAE: 7.6724
#   RMSE: 13.9534
#
# D3 Regression Performance:
#   R² Score: 0.6375
#   MAE: 4.7607
#   RMSE: 10.5024
#
# D4 Regression Performance:
#   R² Score: 0.0148
#   MAE: 2.0633
#   RMSE: 6.2288
#
# D4 Binary Classification Performance:
#   Accuracy: 0.8828
#   Precision: 0.4666
#   Recall: 0.4652
#   F1 Score: 0.4645
#
#
# KEY ACHIEVEMENTS:
# 1. Successfully implemented TreeFFuser for probabilistic drought predictions
# 2. Fixed dimension and data type compatibility issues
# 3. Added comprehensive D4 binary classification
# 4. Implemented proper time series cross-validation
# 5. Applied domain knowledge constraints for physical consistency
# 6. Generated uncertainty quantification using sampling capability
#
# VISUALIZATION AND RESULTS:
# All predictions, visualizations, and performance metrics have been saved to the results directory:
# - future_drought_predictions.csv: Predicted drought indices
# - future_drought_predictions_with_binary.csv: Predictions with binary classification
# - performance_metrics.json: Detailed performance metrics
# - drought_predictions.png: Time series visualizations
# - drought_predictions_uncertainty.png: Uncertainty visualization
# - d4_binary_classification.png: D4 classification analysis
#
# Drought prediction model completed successfully.
#
# Total execution time: 353.29 seconds (5.89 minutes)
# Report saved to 'results/model_report.txt'
# Drought prediction completed successfully!
